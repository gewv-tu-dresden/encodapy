# %% [markdown]
# # Component Runner Example
# This notebook shows an example how to run a service with two components. You need to read the [readme.md](./readme.md) and the `.env` file.

# %%
from encodapy.service.service_main import service_main

# %%
await service_main()
# Out:
# 2026-04-29 10:42:07.258 | INFO     | encodapy.service.basic_service:prepare_basic_start:102 - Prepare the basic start of the service
# 2026-04-29 10:42:07.265 | DEBUG    | encodapy.config.models:check_timestep_units:265 - No timestep is set - using default value '1'
# 2026-04-29 10:42:07.272 | DEBUG    | encodapy.config.models:check_timestep_units:267 - No timestep unit is set - using default unit 'second'
# 2026-04-29 10:42:07.273 | DEBUG    | encodapy.config.models:check_timestep_units:275 - No timerange type is set - using default type 'absolute'
# 2026-04-29 10:42:07.276 | DEBUG    | encodapy.service.basic_service:_load_config:95 - Config succesfully loaded.
# 2026-04-29 10:42:07.372 | DEBUG    | encodapy.components.basic_component:set_component_config_data:210 - Static config load_level_check not in static configuration, trying to skip it.
# 2026-04-29 10:42:07.375 | DEBUG    | encodapy.components.basic_component:set_component_config_data:210 - Static config calibration not in static configuration, trying to skip it.
# 2026-04-29 10:42:07.394 | DEBUG    | encodapy.components.basic_component:prepare_component:350 - Prepare component is not implemented in the base class for two_point_controller
# 2026-04-29 10:42:07.397 | INFO     | encodapy.service.basic_service:start_calibration:637 - No Information about the calibration time in the configuration. Calibration will not be performed.
# 2026-04-29 10:42:07.398 | DEBUG    | encodapy.service.basic_service:check_health_status:669 - Start the Health-Check
# 2026-04-29 10:42:07.401 | INFO     | encodapy.service.basic_service:start_service:598 - Start the Service
# 2026-04-29 10:42:07.404 | DEBUG    | encodapy.service.basic_service:start_service:607 - Start the Process
# 2026-04-29 10:42:07.527 | DEBUG    | encodapy.components.thermal_storage.thermal_storage:calculate:645 - Storing thermal storage sensor values.
# 2026-04-29 10:42:07.529 | WARNING  | encodapy.components.thermal_storage.thermal_storage:store_storage_temperature_history:679 - Could not store temperature for sensor 0: Temperature time is not set.
# 2026-04-29 10:42:07.530 | WARNING  | encodapy.components.thermal_storage.thermal_storage:store_storage_temperature_history:679 - Could not store temperature for sensor 1: Temperature time is not set.
# 2026-04-29 10:42:07.530 | WARNING  | encodapy.components.thermal_storage.thermal_storage:store_storage_temperature_history:679 - Could not store temperature for sensor 2: Temperature time is not set.
# 2026-04-29 10:42:07.531 | WARNING  | encodapy.components.thermal_storage.thermal_storage:store_storage_temperature_history:679 - Could not store temperature for sensor 3: Temperature time is not set.
# 2026-04-29 10:42:07.531 | WARNING  | encodapy.components.thermal_storage.thermal_storage:store_storage_temperature_history:679 - Could not store temperature for sensor 4: Temperature time is not set.
# 2026-04-29 10:42:07.534 | DEBUG    | encodapy.components.basic_component:run:453 - Calculated storage__level: 47.95 DataUnits.PERCENT for thermal_storage.
# 2026-04-29 10:42:07.536 | DEBUG    | encodapy.components.basic_component:run:453 - Calculated control_signal: 0.0 None for two_point_controller.
# 2026-04-29 10:42:07.646 | DEBUG    | encodapy.service.basic_service:send_outputs:439 - Finished sending output data
# 2026-04-29 10:42:11.459 | DEBUG    | encodapy.service.basic_service:start_service:628 - Service will be stopped, running cleanup
# 2026-04-29 10:42:11.459 | DEBUG    | encodapy.service.basic_service:cleanup_service:584 - Service stopped, cleanup finished.
# 2026-04-29 10:42:11.459 | INFO     | encodapy.service.service_main:service_main:96 - Service successfully stopped
