# %% [markdown]
# # weather_Data  Component
# This notebook provides an opportunity to run the weather_data component. You need to read the [readme.md](./readme.md) and the `.env` file.

# %%
from dotenv import load_dotenv
from encodapy.service.service_main import service_main

load_dotenv()
print(f"Loaded env: {load_dotenv()}")

await service_main()
# Out:
# Loaded env: True
# 2026-09-11 13:16:20.430 | INFO     | encodapy.service.basic_service:prepare_basic_start:103 - Prepare the basic start of the service
# 2026-09-11 13:16:20.434 | DEBUG    | encodapy.service.communication.file_connection:load_file_params:54 - Load config for File interface
# 2026-09-11 13:16:20.438 | DEBUG    | encodapy.service.basic_service:_load_config:96 - Config succesfully loaded.
# 2026-09-11 13:16:23.570 | DEBUG    | encodapy.components.weather_data.weather_data:prepare_component:64 - Hello from WeatherData! Preparing Calculation part depending in the output-configuration.
# 2026-09-11 13:16:23.572 | INFO     | encodapy.service.basic_service:start_calibration:766 - No Information about the calibration time in the configuration. Calibration will not be performed.
# 2026-09-11 13:16:23.573 | DEBUG    | encodapy.service.basic_service:check_health_status:798 - Start the Health-Check
# ...
