# %%
from dotenv import load_dotenv
from main import main

# %%
load_dotenv()
print(f"Loaded env: {load_dotenv()}")
# Out:
# Loaded env: True

# %%
await main()
# Out:
# 2025-08-13 13:35:09.791 | INFO     | encodapy.service.basic_service:prepare_basic_start:93 - Prepare the basic start of the service
# 2025-08-13 13:35:09.791 | DEBUG    | encodapy.config.models:check_timestep_units:216 - No timestep is set - using default value '1'
# 2025-08-13 13:35:09.795 | DEBUG    | encodapy.config.models:check_timestep_units:218 - No timestep unit is set - using default unit 'second'
# 2025-08-13 13:35:09.797 | DEBUG    | encodapy.config.models:check_timestep_units:226 - No timerange type is set - using default type 'absolute'
# 2025-08-13 13:35:09.799 | DEBUG    | encodapy.service.basic_service:_load_config:84 - ENVs succesfully loaded.
# 2025-08-13 13:35:09.922 | DEBUG    | encodapy.service.basic_service:start_calibration:608 - Start Calibration
# 2025-08-13 13:35:09.935 | DEBUG    | encodapy.service.basic_service:check_health_status:621 - Start the the Health-Check
# ...
