# %%
from dotenv import load_dotenv
from main import main
# Out:
# c:\Users\marti\AppData\Local\pypoetry\Cache\virtualenvs\encodapy-yCtKR3Ss-py3.11\Lib\site-packages\filip\clients\ngsi_v2\cb.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %%
loaded_env = load_dotenv(".env")
print(f"Loaded env: {loaded_env}")
# Out:
# Loaded env: True

# %%
await main()
# Out:
# 2025-07-03 13:08:45.209 | INFO     | encodapy.service.basic_service:prepare_basic_start:100 - Prepare the basic start of the service
# 2025-07-03 13:08:45.211 | DEBUG    | encodapy.config.models:check_timestep_units:235 - No timestep is set - using default value '1'
# 2025-07-03 13:08:45.213 | DEBUG    | encodapy.config.models:check_timestep_units:237 - No timestep unit is set - using default unit 'second'
# 2025-07-03 13:08:45.214 | DEBUG    | encodapy.config.models:check_timestep_units:239 - No sampling time is set - using default value '1'
# 2025-07-03 13:08:45.214 | DEBUG    | encodapy.config.models:check_timestep_units:241 - No sampling time unit is set - using default unit 'minute'
# 2025-07-03 13:08:45.215 | DEBUG    | encodapy.config.models:check_timestep_units:245 - No timerange type is set - using default type 'absolute'
# 2025-07-03 13:08:45.216 | DEBUG    | encodapy.service.basic_service:_load_config:91 - ENVs succesfully loaded.
# 2025-07-03 13:08:45.219 | DEBUG    | encodapy.service.basic_service:start_calibration:608 - Start Calibration
# 2025-07-03 13:08:45.240 | DEBUG    | encodapy.service.basic_service:check_health_status:621 - Start the the Health-Check
# 2025-07-03 13:08:45.242 | INFO     | encodapy.service.basic_service:start_service:555 - Start the Service
# 2025-07-03 13:08:45.243 | DEBUG    | encodapy.service.basic_service:start_service:558 - Start the Prozess
# 2025-07-03 13:08:45.302 | DEBUG    | encodapy.service.basic_service:calibration:451 - No calibration function implemented, get the data only: {"input_entities":[{"id":"thermal_storage","attributes":[{"id":"temperature_1","data":80.0,"unit":"CEL","data_type":"value","data_available":true,"latest_timestamp_input":null},{"id":"temperature_2","data":78.0,"unit":"CEL","data_type":"value","data_available":true,"latest_timestamp_input":null},{"id":"temperature_3","data":72.0,"unit":"CEL","data_type":"value","data_available":true,"latest_timestamp_input":null},{"id":"temperature_4","data":70.0,"unit":"CEL","data_type":"value","data_available":true,"latest_timestamp_input":null},{"id":"temperature_5","data":68.0,"unit":"CEL","data_type":"value","data_available":true,"latest_timestamp_input":null}]}],"output_entities":[{"id":"thermal_storage","attributes":[],"attributes_status":[{"id":"storage__energy","latest_timestamp_output":"2025-07-03T10:51:10Z"},{"id":"storage__level","latest_timestamp_output":"2025-07-03T10:51:10Z"}],"commands":[]}],"static_entities":[]}
# 2025-07-03 13:08:45.329 | DEBUG    | encodapy.service.communication.fiware_connection:_send_data_to_fiware:931 - No information about the unit of the attribute storage__level from entity thermal_storage available!
# 2025-07-03 13:08:45.335 | DEBUG    | encodapy.service.communication.fiware_connection:_send_data_to_fiware:931 - No information about the unit of the attribute storage__energy from entity thermal_storage available!
# 2025-07-03 13:08:45.349 | DEBUG    | encodapy.service.basic_service:send_outputs:407 - Finished sending output data
