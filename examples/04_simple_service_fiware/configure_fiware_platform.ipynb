# %%
"""
Description: This module contains the configuration for the data points of the example service
Author: Martin Altenburger
"""
import os
from loguru import logger
from filip.models.base import FiwareHeader
from filip.clients.ngsi_v2 import IoTAClient, ContextBrokerClient
from filip.models.ngsi_v2.iot import ServiceGroup
from filip.models.ngsi_v2.subscriptions import Subscription
from filip.models.ngsi_v2.context import ContextEntity, NamedContextAttribute, NamedCommand
from filip.models.ngsi_v2.base import NamedMetadata
from filip.models.base import DataType
from dotenv import load_dotenv

# %% [markdown]
# The following environment variables are required. Please provide them in the [.env](.env) file:
# ```
# FIWARE_IOTA= ["http://127.0.0.1:4041"]      # URL of the IoT Agent
# FIWARE_CB= ["http://127.0.0.1:1026"]        # URL of the Context Broker
# FIWARE_SERVICE= ["example_service"]         # Name of the FIWARE Service
# FIWARE_SERVICE_PATH= ["/"]                  # FIWARE Service Path, usually "/"
# ```
#
# You must have access to the required Fiware platform.

# %%
load_dotenv()
# Out:
# True

# %%
logger.info("Starting service configuration")
fiware_header = FiwareHeader(service=os.getenv("FIWARE_SERVICE"),
                             service_path=os.getenv("FIWARE_SERVICE_PATH"))
logger.info("Creating clients for IoT Agent and Context Broker")
iota_client = IoTAClient(url=os.getenv("FIWARE_IOTA"),
                         fiware_header=fiware_header)
logger.info("IoT Agent client created with url")
cb_client = ContextBrokerClient(url=os.getenv("FIWARE_CB"),
                                fiware_header=fiware_header)
logger.info("Context Broker client created with url")


def create_service():
    """
    Function to create a service group for the example service
    """
    groups = iota_client.get_group_list()
    for group in groups:
        if (group.service == os.getenv("FIWARE_SERVICE")
            and group.subservice == os.getenv("FIWARE_SERVICE_PATH")):
            logger.info("Service group already exists")
            return False

    service_group = ServiceGroup(service=os.getenv("FIWARE_SERVICE"),
                                 subservice=os.getenv("FIWARE_SERVICE_PATH"),
                                 apikey=os.getenv("FIWARE_SERVICE"),
                                 entity_type="example_service",
                                 resource="/iot/json",
                                 explicitAttrs=True,
                                 autoprovision=False)

    iota_client.post_group(service_group=service_group,
                           update=True)
    
    return True

def create_subscription():
    """
    Function to create a subscription for the example service -- if needed
    
    The subscription is used to notify at all changes of all components
    """
    subscription = Subscription(
        description="Notification of all changes",
        subject={
            "entities": [
                    {
                        "idPattern": ".*",
                        "type": "example_service"
                    }
                ],
                "condition": {
                    "attrs": []
                }
        },
        notification={
            "http": {
                "url": os.getenv("FIWARE_QL") + "/v2/notify"
            },
            "attrs": [],
            "metadata": ["TimeInstant"],
            "onlyChangedAttrs": False
        }
    )

    cb_client.post_subscription(subscription=subscription)
    
def create_entities():
    """
    Function to create the required entities for the example service
    """
    entities = [
        {
            "id": "urn:thermal_storage:01",
            "type": "thermal_storage",
            "attributes": [
                {
                    "id": "temperature__measured",
                    "type": "Number",
                    "value": 49,
                    "metadata": {
                        "unitCode":"CEL"
                        }
                },
                {
                    "id": "temperature__setpoint",
                    "type": "Number",
                    "value": 60,
                    "metadata": {
                        "unitCode":"CEL"
                        }
                }
            ],
            "cmds": []
        },
        {
            "id": "urn:heater:01",
            "type": "heater",
            "attributes": [{
                    "id": "power__rated",
                    "type": "Number",
                    "value": 15,
                    "metadata": {
                        "unitCode":"KWT"
                        }
                }# only for testing, not used in the service
                # ,{
                #     "id": "operation__setpoint_test",
                #     "type": "Number",
                #     "value": 0,
                #     "metadata": {
                #         "unitCode":"KWT"
                #         }
                # }
                ],
            "cmds": [
                {
                    "id": "operation__setpoint",
                    "value": 0
                }
            ]
        }
    ]
    
    for entity_raw in entities:
        logger.debug("Creating entity with id: " + entity_raw["id"])
        entity = ContextEntity(id=entity_raw["id"],
                               type=entity_raw["type"])
        
        attrs = []
        if "attributes" in entity_raw and len(entity_raw["attributes"])>0: 
            for attribute in entity_raw["attributes"]:
                
                metadata = []
                for key, value in attribute["metadata"].items():
                    metadata.append(NamedMetadata(name=key, value=value, type="Text"))
                
                attrs.append(NamedContextAttribute(name=attribute["id"],
                                                type=attribute["type"],
                                                value=attribute["value"],
                                                metadata=metadata))
        if "cmds" in entity_raw and len(entity_raw["cmds"])>0:    
            for cmd in entity_raw["cmds"]:
                attrs.append(NamedCommand(name=cmd["id"],
                                          type=DataType.COMMAND,
                                          value=cmd["value"]))
        
        entity.add_attributes(attrs)
        logger.debug(f"Posting entity: {entity}")
        
        cb_client.post_entity(entity=entity,
                              update=True)
        logger.info(f"Entity with id {entity_raw['id']} created/updated")


def prepare_service():
    """
    Function to prepare the service, entitys and subscriptions
    """
    logger.info("Start creating service and subscription")
    new_service = create_service()
    if new_service is False:
        logger.info("Service is already available")
        
    create_entities()


prepare_service()
# Out:
# 2026-02-16 16:11:30.774 | INFO     | __main__:<module>:1 - Starting service configuration
# 2026-02-16 16:11:30.778 | INFO     | __main__:<module>:4 - Creating clients for IoT Agent and Context Broker
# 2026-02-16 16:11:30.783 | INFO     | __main__:<module>:8 - IoT Agent client created with url
# 2026-02-16 16:11:30.833 | INFO     | __main__:<module>:12 - Context Broker client created with url
# 2026-02-16 16:11:30.838 | INFO     | __main__:prepare_service:162 - Start creating service and subscription
# 2026-02-16 16:11:30.932 | INFO     | __main__:create_service:23 - Service group already exists
# 2026-02-16 16:11:30.935 | INFO     | __main__:prepare_service:165 - Service is already available
# 2026-02-16 16:11:30.937 | DEBUG    | __main__:create_entities:128 - Creating entity with id: urn:thermal_storage:01
# 2026-02-16 16:11:30.949 | DEBUG    | __main__:create_entities:151 - Posting entity: id='urn:thermal_storage:01' type='thermal_storage' temperature__measured=ContextAttribute(type='Number', value=49.0, metadata={'unitCode': Metadata(type='Text', value='CEL')}) temperature__setpoint=ContextAttribute(type='Number', value=60.0, metadata={'unitCode': Metadata(type='Text', value='CEL')})
# 2026-02-16 16:11:30.983 | INFO     | __main__:create_entities:155 - Entity with id urn:thermal_storage:01 created/updated
# http://127.0.0.1:4041
# http://127.0.0.1:1026
# 2026-02-16 16:11:30.985 | DEBUG    | __main__:create_entities:128 - Creating entity with id: urn:heater:01
# 2026-02-16 16:11:30.998 | DEBUG    | __main__:create_entities:151 - Posting entity: id='urn:heater:01' type='heater' power__rated=ContextAttribute(type='Number', value=15.0, metadata={'unitCode': Metadata(type='Text', value='KWT')}) operation__setpoint_test=ContextAttribute(type='Number', value=0.0, metadata={'unitCode': Metadata(type='Text', value='KWT')}) operation__setpoint=ContextAttribute(type=<DataType.COMMAND: 'command'>, value=0, metadata={})
# 2026-02-16 16:11:31.033 | INFO     | __main__:create_entities:155 - Entity with id urn:heater:01 created/updated

# %%
cb_client.get_entity(entity_id="urn:heater:01")
# Out:
# ContextEntity(id='urn:heater:01', type='heater', operation__setpoint=ContextAttribute(type='command', value=0, metadata={}), operation__setpoint_test=ContextAttribute(type='Number', value=0.0, metadata={'unitCode': Metadata(type='Text', value='KWT')}), power__rated=ContextAttribute(type='Number', value=15.0, metadata={'unitCode': Metadata(type='Text', value='KWT')}))
