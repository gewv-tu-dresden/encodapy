# %%
from encodapy.service.service_main import service_main
from example_service import ExampleService

# %%
await service_main(service_class=ExampleService)
# Out:
# 2026-02-13 17:10:01.428 | DEBUG    | encodapy.service.service_main:signal_handler:49 - Shutdown signal received, end service properly...
