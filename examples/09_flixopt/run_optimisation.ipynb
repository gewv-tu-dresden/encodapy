# %% [markdown]
# # Example for FlixOpt Component
# This notebook shows an example how to run a service with two components. You need to read the [readme.md](./readme.md) and the `.env` file.

# %%
from encodapy.service.service_main import service_main

# %%
await service_main()
# Out:
# 2025-12-05 15:51:48.449 | INFO     | encodapy.service.basic_service:prepare_basic_start:96 - Prepare the basic start of the service
# 2025-12-05 15:51:48.464 | DEBUG    | encodapy.config.models:check_timestep_units:274 - No timerange type is set - using default type 'absolute'
# 2025-12-05 15:51:48.466 | DEBUG    | encodapy.service.communication.file_connection:load_file_params:54 - Load config for File interface
# 2025-12-05 15:51:48.468 | DEBUG    | encodapy.service.basic_service:_load_config:88 - Config succesfully loaded.
# 2025-12-05 15:51:48.469 | DEBUG    | encodapy.components.basic_component:set_component_config_data:210 - Static config flixopt_log_level not in static configuration, trying to skip it.
# 2025-12-05 15:51:48.472 | INFO     | encodapy.service.basic_service:start_calibration:623 - No Information about the calibration time in the configuration. Calibration will not be performed.
# 2025-12-05 15:51:48.472 | DEBUG    | encodapy.service.basic_service:check_health_status:651 - Start the Health-Check
# 2025-12-05 15:51:48.475 | INFO     | encodapy.service.basic_service:start_service:585 - Start the Service
# 2025-12-05 15:51:48.477 | DEBUG    | encodapy.service.basic_service:start_service:593 - Start the Process
# 2025-12-05 15:51:48.479 | DEBUG    | encodapy.service.communication.file_connection:get_data_from_file:112 - load inputdata from .csv -file
# 2025-12-05 15:51:53.349 | DEBUG    | encodapy.components.basic_component:run:453 - Calculated boiler_heat_output: time
# 2025-01-01 00:00:00    30.0
# 2025-01-01 01:00:00     0.0
# 2025-01-01 02:00:00    -0.0
# 2025-01-01 03:00:00     0.0
# 2025-01-01 04:00:00     0.0
# 2025-01-01 05:00:00     0.0
# Name: boiler_heat_output, dtype: float64 DataUnits.WHR for new_component.
# 2025-12-05 15:51:53.349 | DEBUG    | encodapy.components.basic_component:run:453 - Calculated chp_heat_output: time
# 2025-01-01 00:00:00    25.56
# 2025-01-01 01:00:00    45.40
# 2025-01-01 02:00:00    55.56
# 2025-01-01 03:00:00    45.44
# 2025-01-01 04:00:00    47.44
# 2025-01-01 05:00:00    48.44
# Name: chp_heat_output, dtype: float64 DataUnits.WHR for new_component.
# 2025-12-05 15:51:53.349 | DEBUG    | encodapy.components.basic_component:run:453 - Calculated chp_electric_output: time
# 2025-01-01 00:00:00    20.44
# 2025-01-01 01:00:00    36.32
# 2025-01-01 02:00:00    44.44
# 2025-01-01 03:00:00    36.36
# 2025-01-01 04:00:00    37.96
# 2025-01-01 05:00:00    38.76
# Name: chp_electric_output, dtype: float64 DataUnits.WHR for new_component.
# 2025-12-05 15:51:53.349 | DEBUG    | encodapy.components.basic_component:run:453 - Calculated thermal_storage_charge_state: time
# 2025-01-01 00:00:00    0.0
# 2025-01-01 01:00:00    5.0
# 2025-01-01 02:00:00    0.0
# 2025-01-01 03:00:00    5.0
# 2025-01-01 04:00:00    5.0
# 2025-01-01 05:00:00    5.0
# Name: thermal_storage_charge_state, dtype: float64 DataUnits.WHR for new_component.
# 2025-12-05 15:51:53.349 | DEBUG    | encodapy.service.basic_service:send_outputs:417 - Finished sending output data
# 2025-12-05 15:51:54.970 | DEBUG    | encodapy.service.basic_service:start_service:614 - Service will be stopped, running cleanup
# 2025-12-05 15:51:54.970 | DEBUG    | encodapy.service.basic_service:cleanup_service:571 - Service stopped, cleanup finished.
# 2025-12-05 15:51:54.971 | INFO     | encodapy.service.service_main:service_main:96 - Service successfully stopped
