# %% [markdown]
# # Example for FlixOpt Component
# This notebook shows an example how to run a service with two components. You need to read the [readme.md](./readme.md) and add the `.env` file:
#
# ```
# LOG_LEVEL = "DEBUG"
# FILE_PATH_OF_INPUT_FILE = "./inputs_flixopt.csv"
# CONFIG_PATH = "./config_example.json"
# ```

# %%
from encodapy.service.service_main import service_main

# %%
await service_main()
# Out:
# 2026-04-02 16:53:08.370 | INFO     | encodapy.service.basic_service:prepare_basic_start:101 - Prepare the basic start of the service
# 2026-04-02 16:53:08.373 | DEBUG    | encodapy.config.models:check_timestep_units:275 - No timerange type is set - using default type 'absolute'
# 2026-04-02 16:53:08.375 | DEBUG    | encodapy.service.communication.file_connection:load_file_params:54 - Load config for File interface
# 2026-04-02 16:53:08.380 | DEBUG    | encodapy.service.basic_service:_load_config:93 - Config succesfully loaded.
# 2026-04-02 16:53:08.383 | DEBUG    | encodapy.components.basic_component:set_component_config_data:208 - Static config excess_penalty not in static configuration, trying to skip it.
# 2026-04-02 16:53:08.393 | INFO     | encodapy.service.basic_service:start_calibration:639 - No Information about the calibration time in the configuration. Calibration will not be performed.
# 2026-04-02 16:53:08.395 | DEBUG    | encodapy.service.basic_service:check_health_status:671 - Start the Health-Check
# 2026-04-02 16:53:08.398 | INFO     | encodapy.service.basic_service:start_service:601 - Start the Service
# 2026-04-02 16:53:08.400 | DEBUG    | encodapy.service.basic_service:start_service:609 - Start the Process
# 2026-04-02 16:53:08.401 | DEBUG    | encodapy.service.communication.file_connection:get_data_from_file:112 - load inputdata from .csv -file
# 2026-04-02 16:53:08.414 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for heat_demand: {'entity': 'flixopt_input_entity', 'attribute': 'heat_demand'}
# 2026-04-02 16:53:08.417 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for electricity_demand: {'entity': 'flixopt_input_entity', 'attribute': 'electricity_demand'}
# 2026-04-02 16:53:08.419 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for electricity_price: {'entity': 'flixopt_input_entity', 'attribute': 'electricity_price'}
# 2026-04-02 16:53:08.421 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for storage_level: {'entity': 'flixopt_input_test', 'attribute': 'storage_level'}
# 2026-04-02 16:53:08.423 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:300 - Processing input heat_demand with value type <class 'dict'>
# 2026-04-02 16:53:08.426 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:300 - Processing input electricity_demand with value type <class 'dict'>
# 2026-04-02 16:53:08.430 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:300 - Processing input electricity_price with value type <class 'dict'>
# 2026-04-02 16:53:08.435 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:300 - Processing input storage_level with value type <class 'dict'>
# 2026-04-02 16:53:08.441 INFO     │ Registered new Bus: heat
# 2026-04-02 16:53:08.445 INFO     │ Registered new Bus: gas
# 2026-04-02 16:53:08.446 INFO     │ Registered new Bus: electricity
# 2026-04-02 16:53:08.448 INFO     │ Registered new Effect: costs
# 2026-04-02 16:53:08.449 INFO     │ Registered new Effect: costs
# 2026-04-02 16:53:08.450 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:_prepare_flixopt_flow_system:365 - Prepared FlowSystem with 3 buses and 1 effects.
# 2026-04-02 16:53:08.456 INFO     │ Registered new Boiler: boiler
# 2026-04-02 16:53:08.458 INFO     │ Registered new CHP: chp
# 2026-04-02 16:53:08.460 INFO     │ Registered new Sink: heat_demand
# 2026-04-02 16:53:08.460 INFO     │ Registered new Source: gas_supply
# 2026-04-02 16:53:08.461 INFO     │ Registered new Sink: electricity_demand
# 2026-04-02 16:53:08.463 INFO     │ Registered new SourceAndSink: electricity_network
# 2026-04-02 16:53:08.465 INFO     │ Registered new Storage: thermal_storage
# 2026-04-02 16:53:08.466 INFO     │ Registered new LinearConverter: GasEngine
# 2026-04-02 16:53:08.469 DEBUG    │ Connected 3 Buses and 8 via 14 Flows inside the FlowSystem.
# 2026-04-02 16:53:08.471 DEBUG    │ Auto-assigned color '#636EFA' to component 'boiler'
# 2026-04-02 16:53:08.474 DEBUG    │ Auto-assigned color '#EF553B' to component 'chp'
# 2026-04-02 16:53:08.475 DEBUG    │ Auto-assigned color '#00CC96' to component 'heat_demand'
# 2026-04-02 16:53:08.476 DEBUG    │ Auto-assigned color '#AB63FA' to component 'gas_supply'
# 2026-04-02 16:53:08.477 DEBUG    │ Auto-assigned color '#FFA15A' to component 'electricity_demand'
# 2026-04-02 16:53:08.478 DEBUG    │ Auto-assigned color '#19D3F3' to component 'electricity_network'
# 2026-04-02 16:53:08.479 DEBUG    │ Auto-assigned color '#FF6692' to component 'thermal_storage'
# 2026-04-02 16:53:08.481 DEBUG    │ Auto-assigned color '#B6E880' to component 'GasEngine'
# 2026-04-02 16:53:08.494 DEBUG    │ Creating EffectCollectionModel  "Effects"
# 2026-04-02 16:53:08.495 INFO     │ Auto-created Penalty Effect: Penalty
# 2026-04-02 16:53:08.496 DEBUG    │ Creating EffectModel  "costs"
# 2026-04-02 16:53:08.498 DEBUG    │ Creating ShareAllocationModel  "costs(periodic)"
# 2026-04-02 16:53:08.511 DEBUG    │ Creating ShareAllocationModel  "costs(temporal)"
# 2026-04-02 16:53:08.627 DEBUG    │ Creating EffectModel  "Penalty"
# 2026-04-02 16:53:08.629 DEBUG    │ Creating ShareAllocationModel  "Penalty(periodic)"
# 2026-04-02 16:53:08.647 DEBUG    │ Creating ShareAllocationModel  "Penalty(temporal)"
# 2026-04-02 16:53:08.793 DEBUG    │ Creating LinearConverterModel  "boiler"
# 2026-04-02 16:53:08.797 DEBUG    │ Creating FlowModel  "boiler(gas)"
# 2026-04-02 16:53:08.810 DEBUG    │ Creating StatusModel  "boiler(gas)"
# 2026-04-02 16:53:08.943 DEBUG    │ Creating FlowModel  "boiler(heat)"
# 2026-04-02 16:53:08.957 DEBUG    │ Creating StatusModel  "boiler(heat)"
# 2026-04-02 16:53:09.229 DEBUG    │ Creating StatusModel  "boiler"
# 2026-04-02 16:53:09.629 DEBUG    │ Creating LinearConverterModel  "chp"
# 2026-04-02 16:53:09.634 DEBUG    │ Creating FlowModel  "chp(gas)"
# 2026-04-02 16:53:09.647 DEBUG    │ Creating StatusModel  "chp(gas)"
# 2026-04-02 16:53:09.849 DEBUG    │ Creating FlowModel  "chp(heat)"
# 2026-04-02 16:53:09.874 DEBUG    │ Creating StatusModel  "chp(heat)"
# 2026-04-02 16:53:10.111 DEBUG    │ Creating FlowModel  "chp(electricity)"
# 2026-04-02 16:53:10.124 DEBUG    │ Creating StatusModel  "chp(electricity)"
# 2026-04-02 16:53:10.571 DEBUG    │ Creating StatusModel  "chp"
# 2026-04-02 16:53:11.111 DEBUG    │ Creating ComponentModel  "heat_demand"
# 2026-04-02 16:53:11.115 DEBUG    │ Creating FlowModel  "heat_demand(heat_in)"
# 2026-04-02 16:53:11.169 DEBUG    │ Creating ComponentModel  "gas_supply"
# 2026-04-02 16:53:11.172 DEBUG    │ Creating FlowModel  "gas_supply(gas_out)"
# 2026-04-02 16:53:11.360 DEBUG    │ Creating ComponentModel  "electricity_demand"
# 2026-04-02 16:53:11.364 DEBUG    │ Creating FlowModel  "electricity_demand(electricity_in)"
# 2026-04-02 16:53:11.422 DEBUG    │ Creating ComponentModel  "electricity_network"
# 2026-04-02 16:53:11.427 DEBUG    │ Creating FlowModel  "electricity_network(electricity_in)"
# 2026-04-02 16:53:11.445 DEBUG    │ Creating StatusModel  "electricity_network(electricity_in)"
# 2026-04-02 16:53:11.754 DEBUG    │ Creating FlowModel  "electricity_network(electricity_out)"
# 2026-04-02 16:53:11.767 DEBUG    │ Creating StatusModel  "electricity_network(electricity_out)"
# 2026-04-02 16:53:12.113 DEBUG    │ Creating StorageModel  "thermal_storage"
# 2026-04-02 16:53:12.116 DEBUG    │ Creating FlowModel  "thermal_storage(heat_charge)"
# 2026-04-02 16:53:12.130 DEBUG    │ Creating StatusModel  "thermal_storage(heat_charge)"
# 2026-04-02 16:53:12.306 DEBUG    │ Creating FlowModel  "thermal_storage(heat_discharge)"
# 2026-04-02 16:53:12.328 DEBUG    │ Creating StatusModel  "thermal_storage(heat_discharge)"
# 2026-04-02 16:53:12.952 DEBUG    │ Creating LinearConverterModel  "GasEngine"
# 2026-04-02 16:53:12.958 DEBUG    │ Creating FlowModel  "GasEngine(gas)"
# 2026-04-02 16:53:13.029 DEBUG    │ Creating FlowModel  "GasEngine(electricity)"
# 2026-04-02 16:53:13.095 DEBUG    │ Creating PiecewiseModel  "GasEngine"
# 2026-04-02 16:53:13.098 DEBUG    │ Creating PieceModel  "GasEngine|Piece_0"
# 2026-04-02 16:53:13.204 DEBUG    │ Creating PieceModel  "GasEngine|Piece_1"
# 2026-04-02 16:53:13.306 DEBUG    │ Creating PieceModel  "GasEngine|Piece_2"
# 2026-04-02 16:53:13.936 DEBUG    │ Creating BusModel  "heat"
# 2026-04-02 16:53:14.292 DEBUG    │ Creating BusModel  "gas"
# 2026-04-02 16:53:14.416 DEBUG    │ Creating BusModel  "electricity"
# 2026-04-02 16:53:14.821 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:44 -  Solve problem using Highs solver
# 2026-04-02 16:53:14.824 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:44 - Solver logs written to `c:\Users\marti\Documents\Projekte\Projekt_E3\e3_services_mpc\encodapy\examples\09_flixopt\results\encodapy.log`.
# 2026-04-02 16:53:14.829 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:44 - Solver options:
#  - mip_rel_gap: 0.01
#  - time_limit: 60
#  - log_to_console: True
# 2026-04-02 16:53:16.088 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:44 - Writing objective.
# Writing constraints.: 100%|██████████| 87/87 [00:01<00:00, 55.18it/s]
# Writing continuous variables.: 100%|██████████| 66/66 [00:00<00:00, 184.26it/s]
# Writing binary variables.: 100%|██████████| 14/14 [00:00<00:00, 162.95it/s]
# 2026-04-02 16:53:18.136 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:44 -  Writing time: 2.05s
# 2026-04-02 16:53:18.141 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:44 - Log file at C:\Users\marti\Documents\Projekte\Projekt_E3\e3_services_mpc\encodapy\examples\09_flixopt\results\encodapy.log
# 2026-04-02 16:53:18.598 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:44 -  Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 914 primals, 1001 duals
# Objective: -3.12e+00
# Solver model: available
# Solver message: Optimal
#
# 2026-04-02 16:53:19.231 SUCCESS  │ Model solved with highs in 4.42 seconds.
# 2026-04-02 16:53:19.231 INFO     │ Model status after solve: ok
# 2026-04-02 16:53:19.430 DEBUG    │ Skipping name='timesteps' because it is an Index
# 2026-04-02 16:53:20.318 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:run_optimization:922 - Optimization completed with a duration for modeling 6.35 s and solving 4.42 s. The main objective result is -3.12.
# 2026-04-02 16:53:20.463 | DEBUG    | encodapy.service.basic_service:send_outputs:433 - Finished sending output data
# 2026-04-02 16:53:27.013 | DEBUG    | encodapy.service.basic_service:start_service:630 - Service will be stopped, running cleanup
# 2026-04-02 16:53:27.014 | DEBUG    | encodapy.service.basic_service:cleanup_service:587 - Service stopped, cleanup finished.
# 2026-04-02 16:53:27.017 | INFO     | encodapy.service.service_main:service_main:96 - Service successfully stopped
