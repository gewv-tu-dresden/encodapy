# %% [markdown]
# # Example for FlixOpt Component
# This notebook shows an example how to run a service with two components. You need to read the [readme.md](./readme.md) and add the `.env` file:
#
# ```
# LOG_LEVEL = "DEBUG"
# FILE_PATH_OF_INPUT_FILE = "./inputs_flixopt.csv"
# CONFIG_PATH = "./config_example.json"
# ```

# %%
from encodapy.service.service_main import service_main

# %%
await service_main()
# Out:
# 2026-02-06 16:31:37.040 | INFO     | encodapy.service.basic_service:prepare_basic_start:96 - Prepare the basic start of the service
# 2026-02-06 16:31:37.047 | DEBUG    | encodapy.config.models:check_timestep_units:274 - No timerange type is set - using default type 'absolute'
# 2026-02-06 16:31:37.052 | DEBUG    | encodapy.service.communication.file_connection:load_file_params:54 - Load config for File interface
# 2026-02-06 16:31:37.056 | DEBUG    | encodapy.service.basic_service:_load_config:88 - Config succesfully loaded.
# 2026-02-06 16:31:43.987 | DEBUG    | encodapy.components.basic_component:set_component_config_data:209 - Static config excess_penalty not in static configuration, trying to skip it.
# 2026-02-06 16:31:43.997 | INFO     | encodapy.service.basic_service:start_calibration:623 - No Information about the calibration time in the configuration. Calibration will not be performed.
# 2026-02-06 16:31:44.000 | DEBUG    | encodapy.service.basic_service:check_health_status:651 - Start the Health-Check
# 2026-02-06 16:31:44.003 | INFO     | encodapy.service.basic_service:start_service:585 - Start the Service
# 2026-02-06 16:31:44.003 | DEBUG    | encodapy.service.basic_service:start_service:593 - Start the Process
# 2026-02-06 16:31:44.003 | DEBUG    | encodapy.service.communication.file_connection:get_data_from_file:112 - load inputdata from .csv -file
# 2026-02-06 16:31:44.036 | DEBUG    | encodapy.components.basic_component:set_input_data:316 - Processing input configuration for heat_demand: {'entity': 'flixopt_input_entity', 'attribute': 'heat_demand'}
# 2026-02-06 16:31:44.037 | DEBUG    | encodapy.components.basic_component:set_input_data:316 - Processing input configuration for electricity_demand: {'entity': 'flixopt_input_entity', 'attribute': 'electricity_demand'}
# 2026-02-06 16:31:44.040 | DEBUG    | encodapy.components.basic_component:set_input_data:316 - Processing input configuration for electricity_price: {'entity': 'flixopt_input_entity', 'attribute': 'electricity_price'}
# 2026-02-06 16:31:44.043 | DEBUG    | encodapy.components.basic_component:set_input_data:316 - Processing input configuration for storage_level: {'entity': 'flixopt_input_test', 'attribute': 'storage_level'}
# 2026-02-06 16:31:44.046 | DEBUG    | examples.09_flixopt.flixopt_model_component.flixopt_model_component:prepare_input_data:138 - Processing input heat_demand with value type <class 'dict'>
# 2026-02-06 16:31:44.052 | DEBUG    | examples.09_flixopt.flixopt_model_component.flixopt_model_component:prepare_input_data:138 - Processing input electricity_demand with value type <class 'dict'>
# 2026-02-06 16:31:44.058 | DEBUG    | examples.09_flixopt.flixopt_model_component.flixopt_model_component:prepare_input_data:138 - Processing input electricity_price with value type <class 'dict'>
# 2026-02-06 16:31:44.061 | DEBUG    | examples.09_flixopt.flixopt_model_component.flixopt_model_component:prepare_input_data:138 - Processing input storage_level with value type <class 'dict'>
# 2026-02-06 16:31:44.072 INFO     │ Registered new Bus: heat
# 2026-02-06 16:31:44.074 INFO     │ Registered new Bus: gas
# 2026-02-06 16:31:44.077 INFO     │ Registered new Bus: electricity
# 2026-02-06 16:31:44.079 INFO     │ Registered new Effect: costs
# 2026-02-06 16:31:44.080 INFO     │ Registered new Effect: costs
# 2026-02-06 16:31:44.081 | DEBUG    | examples.09_flixopt.flixopt_model_component.flixopt_model_component:_prepare_flixopt_flow_system:202 - Prepared FlowSystem with 3 buses and 1 effects.
# 2026-02-06 16:31:44.085 INFO     │ Registered new Boiler: boiler
# 2026-02-06 16:31:44.087 INFO     │ Registered new CHP: chp
# 2026-02-06 16:31:44.090 INFO     │ Registered new Sink: heat_demand
# 2026-02-06 16:31:44.091 INFO     │ Registered new Source: gas_supply
# 2026-02-06 16:31:44.094 INFO     │ Registered new Sink: electricity_demand
# 2026-02-06 16:31:44.097 INFO     │ Registered new SourceAndSink: electricity_network
# 2026-02-06 16:31:44.099 INFO     │ Registered new Storage: thermal_storage
# 2026-02-06 16:31:44.102 DEBUG    │ Connected 3 Buses and 7 via 12 Flows inside the FlowSystem.
# 2026-02-06 16:31:44.104 DEBUG    │ Auto-assigned color '#636EFA' to component 'boiler'
# 2026-02-06 16:31:44.107 DEBUG    │ Auto-assigned color '#EF553B' to component 'chp'
# 2026-02-06 16:31:44.109 DEBUG    │ Auto-assigned color '#00CC96' to component 'heat_demand'
# 2026-02-06 16:31:44.112 DEBUG    │ Auto-assigned color '#AB63FA' to component 'gas_supply'
# 2026-02-06 16:31:44.113 DEBUG    │ Auto-assigned color '#FFA15A' to component 'electricity_demand'
# 2026-02-06 16:31:44.116 DEBUG    │ Auto-assigned color '#19D3F3' to component 'electricity_network'
# 2026-02-06 16:31:44.118 DEBUG    │ Auto-assigned color '#FF6692' to component 'thermal_storage'
# 2026-02-06 16:31:44.574 DEBUG    │ Creating EffectCollectionModel  "Effects"
# 2026-02-06 16:31:44.578 INFO     │ Auto-created Penalty Effect: Penalty
# 2026-02-06 16:31:44.580 DEBUG    │ Creating EffectModel  "costs"
# 2026-02-06 16:31:44.581 DEBUG    │ Creating ShareAllocationModel  "costs(periodic)"
# 2026-02-06 16:31:44.600 DEBUG    │ Creating ShareAllocationModel  "costs(temporal)"
# 2026-02-06 16:31:44.730 DEBUG    │ Creating EffectModel  "Penalty"
# 2026-02-06 16:31:44.734 DEBUG    │ Creating ShareAllocationModel  "Penalty(periodic)"
# 2026-02-06 16:31:44.747 DEBUG    │ Creating ShareAllocationModel  "Penalty(temporal)"
# 2026-02-06 16:31:44.891 DEBUG    │ Creating LinearConverterModel  "boiler"
# 2026-02-06 16:31:44.894 DEBUG    │ Creating FlowModel  "boiler(gas)"
# 2026-02-06 16:31:44.906 DEBUG    │ Creating StatusModel  "boiler(gas)"
# 2026-02-06 16:31:45.080 DEBUG    │ Creating FlowModel  "boiler(heat)"
# 2026-02-06 16:31:45.094 DEBUG    │ Creating StatusModel  "boiler(heat)"
# 2026-02-06 16:31:45.508 DEBUG    │ Creating StatusModel  "boiler"
# 2026-02-06 16:31:45.933 DEBUG    │ Creating LinearConverterModel  "chp"
# 2026-02-06 16:31:45.933 DEBUG    │ Creating FlowModel  "chp(gas)"
# 2026-02-06 16:31:45.946 DEBUG    │ Creating StatusModel  "chp(gas)"
# 2026-02-06 16:31:46.203 DEBUG    │ Creating FlowModel  "chp(heat)"
# 2026-02-06 16:31:46.217 DEBUG    │ Creating StatusModel  "chp(heat)"
# 2026-02-06 16:31:46.380 DEBUG    │ Creating FlowModel  "chp(electricity)"
# 2026-02-06 16:31:46.394 DEBUG    │ Creating StatusModel  "chp(electricity)"
# 2026-02-06 16:31:46.804 DEBUG    │ Creating StatusModel  "chp"
# 2026-02-06 16:31:47.287 DEBUG    │ Creating ComponentModel  "heat_demand"
# 2026-02-06 16:31:47.290 DEBUG    │ Creating FlowModel  "heat_demand(heat_in)"
# 2026-02-06 16:31:47.350 DEBUG    │ Creating ComponentModel  "gas_supply"
# 2026-02-06 16:31:47.355 DEBUG    │ Creating FlowModel  "gas_supply(gas_out)"
# 2026-02-06 16:31:47.395 DEBUG    │ Creating ComponentModel  "electricity_demand"
# 2026-02-06 16:31:47.399 DEBUG    │ Creating FlowModel  "electricity_demand(electricity_in)"
# 2026-02-06 16:31:47.458 DEBUG    │ Creating ComponentModel  "electricity_network"
# 2026-02-06 16:31:47.465 DEBUG    │ Creating FlowModel  "electricity_network(electricity_in)"
# 2026-02-06 16:31:47.479 DEBUG    │ Creating StatusModel  "electricity_network(electricity_in)"
# 2026-02-06 16:31:47.681 DEBUG    │ Creating FlowModel  "electricity_network(electricity_out)"
# 2026-02-06 16:31:47.700 DEBUG    │ Creating StatusModel  "electricity_network(electricity_out)"
# 2026-02-06 16:31:47.975 DEBUG    │ Creating StorageModel  "thermal_storage"
# 2026-02-06 16:31:47.980 DEBUG    │ Creating FlowModel  "thermal_storage(heat_charge)"
# 2026-02-06 16:31:47.996 DEBUG    │ Creating StatusModel  "thermal_storage(heat_charge)"
# 2026-02-06 16:31:48.244 DEBUG    │ Creating FlowModel  "thermal_storage(heat_discharge)"
# 2026-02-06 16:31:48.264 DEBUG    │ Creating StatusModel  "thermal_storage(heat_discharge)"
# 2026-02-06 16:31:48.895 DEBUG    │ Creating BusModel  "heat"
# 2026-02-06 16:31:49.325 DEBUG    │ Creating BusModel  "gas"
# 2026-02-06 16:31:49.453 DEBUG    │ Creating BusModel  "electricity"
# Writing constraints.: 100%|██████████| 74/74 [00:01<00:00, 51.33it/s]
# Writing continuous variables.: 100%|██████████| 53/53 [00:00<00:00, 150.67it/s]
# Writing binary variables.: 100%|██████████| 11/11 [00:00<00:00, 152.88it/s]
# 2026-02-06 16:31:54.373 SUCCESS  │ Model solved with highs in 4.56 seconds.
# 2026-02-06 16:31:54.374 INFO     │ Model status after solve: ok
# 2026-02-06 16:31:54.615 DEBUG    │ Skipping name='timesteps' because it is an Index
# 2026-02-06 16:31:55.850 | DEBUG    | examples.09_flixopt.flixopt_model_component.flixopt_model_component:run_optimization:534 - Optimization completed with a duration for modeling 5.71 s and solving 4.56 s.
# 2026-02-06 16:31:56.009 | DEBUG    | encodapy.service.basic_service:send_outputs:417 - Finished sending output data
# 2026-02-06 16:32:08.795 | DEBUG    | encodapy.service.basic_service:start_service:614 - Service will be stopped, running cleanup
# 2026-02-06 16:32:08.798 | DEBUG    | encodapy.service.basic_service:cleanup_service:571 - Service stopped, cleanup finished.
# 2026-02-06 16:32:08.798 | INFO     | encodapy.service.service_main:service_main:96 - Service successfully stopped
