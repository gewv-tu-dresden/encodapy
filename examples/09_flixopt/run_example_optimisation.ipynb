# %% [markdown]
# # Example for FlixOpt Component
# This notebook shows an example how to run a service with two components. You need to read the [readme.md](./readme.md) and the `.env` file.

# %%
from encodapy.service.service_main import service_main

# %%
await service_main()
# Out:
# 2026-01-12 15:26:11.117 | INFO     | encodapy.service.basic_service:prepare_basic_start:96 - Prepare the basic start of the service
# 2026-01-12 15:26:11.123 | DEBUG    | encodapy.config.models:check_timestep_units:274 - No timerange type is set - using default type 'absolute'
# 2026-01-12 15:26:11.124 | DEBUG    | encodapy.service.communication.file_connection:load_file_params:54 - Load config for File interface
# 2026-01-12 15:26:11.127 | DEBUG    | encodapy.service.basic_service:_load_config:88 - Config succesfully loaded.
# 2026-01-12 15:26:13.706 | DEBUG    | encodapy.components.basic_component:set_component_config_data:210 - Static config excess_penalty not in static configuration, trying to skip it.
# 2026-01-12 15:26:13.711 | INFO     | encodapy.service.basic_service:start_calibration:623 - No Information about the calibration time in the configuration. Calibration will not be performed.
# 2026-01-12 15:26:13.711 | DEBUG    | encodapy.service.basic_service:check_health_status:651 - Start the Health-Check
# 2026-01-12 15:26:13.718 | INFO     | encodapy.service.basic_service:start_service:585 - Start the Service
# 2026-01-12 15:26:13.718 | DEBUG    | encodapy.service.basic_service:start_service:593 - Start the Process
# 2026-01-12 15:26:13.718 | DEBUG    | encodapy.service.communication.file_connection:get_data_from_file:112 - load inputdata from .csv -file
# 2026-01-12 15:26:13.751 INFO     │ Registered new Bus: electricity
# 2026-01-12 15:26:13.751 INFO     │ Registered new Bus: heat
# 2026-01-12 15:26:13.755 INFO     │ Registered new Bus: gas
# 2026-01-12 15:26:13.757 INFO     │ Registered new Effect: costs
# 2026-01-12 15:26:13.758 INFO     │ Registered new Effect: costs
# 2026-01-12 15:26:13.759 INFO     │ Registered new Effect: CO2
# 2026-01-12 15:26:13.759 INFO     │ Registered new Effect: CO2
# 2026-01-12 15:26:13.761 INFO     │ Registered new Effect: PE
# 2026-01-12 15:26:13.762 INFO     │ Registered new Effect: PE
# 2026-01-12 15:26:13.763 INFO     │ Registered new Boiler: boiler
# 2026-01-12 15:26:13.765 INFO     │ Registered new LinearConverter: chp
# 2026-01-12 15:26:13.766 INFO     │ Registered new Sink: heat_demand
# 2026-01-12 15:26:13.767 INFO     │ Registered new Sink: electricity_demand
# 2026-01-12 15:26:13.769 INFO     │ Registered new Source: gas_demand
# 2026-01-12 15:26:13.771 INFO     │ Registered new Sink: electricity_feed_in
# 2026-01-12 15:26:13.771 INFO     │ Registered new Storage: thermal_storage
# 2026-01-12 15:26:13.773 DEBUG    │ Connected 3 Buses and 7 via 11 Flows inside the FlowSystem.
# 2026-01-12 15:26:13.962 DEBUG    │ Creating EffectCollectionModel  "Effects"
# 2026-01-12 15:26:13.962 INFO     │ Auto-created Penalty Effect: Penalty
# 2026-01-12 15:26:13.964 DEBUG    │ Creating EffectModel  "costs"
# 2026-01-12 15:26:13.965 DEBUG    │ Creating ShareAllocationModel  "costs(periodic)"
# 2026-01-12 15:26:13.971 DEBUG    │ Creating ShareAllocationModel  "costs(temporal)"
# 2026-01-12 15:26:14.026 DEBUG    │ Creating EffectModel  "CO2"
# 2026-01-12 15:26:14.026 DEBUG    │ Creating ShareAllocationModel  "CO2(periodic)"
# 2026-01-12 15:26:14.038 DEBUG    │ Creating ShareAllocationModel  "CO2(temporal)"
# 2026-01-12 15:26:14.089 DEBUG    │ Creating EffectModel  "PE"
# 2026-01-12 15:26:14.090 DEBUG    │ Creating ShareAllocationModel  "PE(periodic)"
# 2026-01-12 15:26:14.096 DEBUG    │ Creating ShareAllocationModel  "PE(temporal)"
# 2026-01-12 15:26:14.145 DEBUG    │ Creating EffectModel  "Penalty"
# 2026-01-12 15:26:14.146 DEBUG    │ Creating ShareAllocationModel  "Penalty(periodic)"
# 2026-01-12 15:26:14.151 DEBUG    │ Creating ShareAllocationModel  "Penalty(temporal)"
# 2026-01-12 15:26:14.246 DEBUG    │ Creating LinearConverterModel  "boiler"
# 2026-01-12 15:26:14.249 DEBUG    │ Creating FlowModel  "boiler(Q_fu)"
# 2026-01-12 15:26:14.256 DEBUG    │ Creating OnOffModel  "boiler(Q_fu)"
# 2026-01-12 15:26:14.336 DEBUG    │ Creating FlowModel  "boiler(Q_th)"
# 2026-01-12 15:26:14.341 DEBUG    │ Creating InvestmentModel  "boiler(Q_th)"
# 2026-01-12 15:26:14.399 DEBUG    │ Creating OnOffModel  "boiler(Q_th)"
# 2026-01-12 15:26:14.993 DEBUG    │ Creating OnOffModel  "boiler"
# 2026-01-12 15:26:15.101 DEBUG    │ Creating LinearConverterModel  "chp"
# 2026-01-12 15:26:15.105 DEBUG    │ Creating FlowModel  "chp(Q_fu)"
# 2026-01-12 15:26:15.110 DEBUG    │ Creating OnOffModel  "chp(Q_fu)"
# 2026-01-12 15:26:15.178 DEBUG    │ Creating FlowModel  "chp(P_el)"
# 2026-01-12 15:26:15.185 DEBUG    │ Creating OnOffModel  "chp(P_el)"
# 2026-01-12 15:26:15.260 DEBUG    │ Creating FlowModel  "chp(Q_th)"
# 2026-01-12 15:26:15.269 DEBUG    │ Creating OnOffModel  "chp(Q_th)"
# 2026-01-12 15:26:15.431 DEBUG    │ Creating OnOffModel  "chp"
# 2026-01-12 15:26:15.566 DEBUG    │ Creating PiecewiseModel  "chp"
# 2026-01-12 15:26:15.568 DEBUG    │ Creating PieceModel  "chp|Piece_0"
# 2026-01-12 15:26:15.601 DEBUG    │ Creating PieceModel  "chp|Piece_1"
# 2026-01-12 15:26:15.837 DEBUG    │ Creating ComponentModel  "heat_demand"
# 2026-01-12 15:26:15.841 DEBUG    │ Creating FlowModel  "heat_demand(Q_th_Last)"
# 2026-01-12 15:26:15.861 DEBUG    │ Creating ComponentModel  "electricity_demand"
# 2026-01-12 15:26:15.861 DEBUG    │ Creating FlowModel  "electricity_demand(P_el_Last)"
# 2026-01-12 15:26:15.882 DEBUG    │ Creating ComponentModel  "gas_demand"
# 2026-01-12 15:26:15.884 DEBUG    │ Creating FlowModel  "gas_demand(Q_Gas)"
# 2026-01-12 15:26:15.968 DEBUG    │ Creating ComponentModel  "electricity_feed_in"
# 2026-01-12 15:26:15.968 DEBUG    │ Creating FlowModel  "electricity_feed_in(P_el)"
# 2026-01-12 15:26:16.023 DEBUG    │ Creating StorageModel  "thermal_storage"
# 2026-01-12 15:26:16.025 DEBUG    │ Creating FlowModel  "thermal_storage(Q_th_load)"
# 2026-01-12 15:26:16.031 DEBUG    │ Creating OnOffModel  "thermal_storage(Q_th_load)"
# 2026-01-12 15:26:16.111 DEBUG    │ Creating FlowModel  "thermal_storage(Q_th_unload)"
# 2026-01-12 15:26:16.119 DEBUG    │ Creating OnOffModel  "thermal_storage(Q_th_unload)"
# 2026-01-12 15:26:16.287 DEBUG    │ Creating InvestmentModel  "thermal_storage"
# 2026-01-12 15:26:16.289 DEBUG    │ Creating PiecewiseEffectsModel  "thermal_storage|PiecewiseEffects"
# 2026-01-12 15:26:16.292 DEBUG    │ Creating PiecewiseModel  "thermal_storage|PiecewiseEffects"
# 2026-01-12 15:26:16.294 DEBUG    │ Creating PieceModel  "thermal_storage|Piece_0"
# 2026-01-12 15:26:16.314 DEBUG    │ Creating PieceModel  "thermal_storage|Piece_1"
# 2026-01-12 15:26:16.583 DEBUG    │ Creating BusModel  "electricity"
# 2026-01-12 15:26:16.693 DEBUG    │ Creating BusModel  "heat"
# 2026-01-12 15:26:16.811 DEBUG    │ Creating BusModel  "gas"
# 2026-01-12 15:26:19.641 SUCCESS  │ Model solved with highs in 2.72 seconds.
# 2026-01-12 15:26:19.641 INFO     │ Model status after solve: ok
# 2026-01-12 15:26:19.645 SUCCESS  │ ┌─ ################################# Main Results #################################
#                                  │ │  Objective: 1578.97
#                                  │ │  Penalty:
#                                  │ │      temporal: 0.0
#                                  │ │      periodic: -0.0
#                                  │ │      total: 0.0
#                                  │ │  Effects:
#                                  │ │      CO2 [kg]:
#                                  │ │          temporal: 1178.71
#                                  │ │          periodic: -0.0
#                                  │ │          total: 1178.71
#                                  │ │      costs [€]:
#                                  │ │          temporal: 28.97
#                                  │ │          periodic: 1550.0
#                                  │ │          total: 1578.97
#                                  │ │      PE [kWh_PE]:
#                                  │ │          temporal: -0.0
#                                  │ │          periodic: 105.0
#                                  │ │          total: 105.0
#                                  │ │  Invest-Decisions:
#                                  │ │      Invested:
#                                  │ │          boiler(Q_th): 50.0
#                                  │ │          thermal_storage: 5.0
#                                  │ │      Not invested: {}
#                                  │ │  Buses with excess: []
#                                  │ └─
# 2026-01-12 15:26:19.806 DEBUG    │ Skipping name='timesteps' because it is an Index
# 2026-01-12 15:26:20.383 | DEBUG    | encodapy.components.basic_component:run:453 - Calculated boiler_heat_output: time
# 2025-01-01 00:00:00    30.0
# 2025-01-01 01:00:00     0.0
# 2025-01-01 02:00:00     0.0
# 2025-01-01 03:00:00     0.0
# 2025-01-01 04:00:00     0.0
# 2025-01-01 05:00:00     0.0
# Name: boiler_thermal_energy, dtype: float64 DataUnits.WHR for flixopt_example_component.
# 2026-01-12 15:26:20.384 | DEBUG    | encodapy.components.basic_component:run:453 - Calculated chp_heat_output: time
# 2025-01-01 00:00:00    25.56
# 2025-01-01 01:00:00    45.40
# 2025-01-01 02:00:00    55.56
# 2025-01-01 03:00:00    45.44
# 2025-01-01 04:00:00    47.44
# 2025-01-01 05:00:00    48.44
# Name: chp_thermal_energy, dtype: float64 DataUnits.WHR for flixopt_example_component.
# 2026-01-12 15:26:20.386 | DEBUG    | encodapy.components.basic_component:run:453 - Calculated chp_electric_output: time
# 2025-01-01 00:00:00    21.86
# 2025-01-01 01:00:00    40.15
# 2025-01-01 02:00:00    43.84
# 2025-01-01 03:00:00    40.16
# 2025-01-01 04:00:00    40.89
# 2025-01-01 05:00:00    41.25
# Name: chp_electric_energy, dtype: float64 DataUnits.WHR for flixopt_example_component.
# 2026-01-12 15:26:20.386 | DEBUG    | encodapy.components.basic_component:run:453 - Calculated thermal_storage_charge_state: time
# 2025-01-01 00:00:00    0.0
# 2025-01-01 01:00:00    5.0
# 2025-01-01 02:00:00    0.0
# 2025-01-01 03:00:00    5.0
# 2025-01-01 04:00:00    5.0
# 2025-01-01 05:00:00    5.0
# Name: thermal_storage_charge_state, dtype: float64 DataUnits.WHR for flixopt_example_component.
# 2026-01-12 15:26:20.386 | DEBUG    | encodapy.service.basic_service:send_outputs:417 - Finished sending output data
# 2026-01-12 15:26:25.895 | DEBUG    | encodapy.service.basic_service:start_service:614 - Service will be stopped, running cleanup
# 2026-01-12 15:26:25.895 | DEBUG    | encodapy.service.basic_service:cleanup_service:571 - Service stopped, cleanup finished.
# 2026-01-12 15:26:25.898 | INFO     | encodapy.service.service_main:service_main:96 - Service successfully stopped
