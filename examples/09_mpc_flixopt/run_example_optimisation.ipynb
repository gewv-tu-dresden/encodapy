# %% [markdown]
# # Example for FlixOpt Component
# This notebook shows an example how to run a service with two components. You need to read the [readme.md](./readme.md) and add the `.env` file:
#
# ```
# LOG_LEVEL = "DEBUG"
# FILE_PATH_OF_INPUT_FILE = "./inputs_flixopt.csv"
# ```
#
# Specify the desired configuration in the `.env` file:
# ```
# CONFIG_PATH = "./01_config_example.json"
# ```
# or
# ```
# CONFIG_PATH = "./02_config_example.json"
# FILE_PATH_OF_STATIC_DATA = "./static_data_flixopt.json"
# ```

# %%
from encodapy.service.service_main import service_main

# %%
await service_main()
# Out:
# 2026-06-03 14:16:01.212 | INFO     | encodapy.service.basic_service:prepare_basic_start:102 - Prepare the basic start of the service
# 2026-06-03 14:16:01.215 | DEBUG    | encodapy.config.models:check_timestep_units:275 - No timerange type is set - using default type 'absolute'
# 2026-06-03 14:16:01.217 | DEBUG    | encodapy.service.communication.file_connection:load_file_params:54 - Load config for File interface
# 2026-06-03 14:16:01.221 | DEBUG    | encodapy.service.basic_service:_load_config:95 - Config succesfully loaded.
# 2026-06-03 14:16:03.397 | DEBUG    | encodapy.components.basic_component:set_component_config_data:208 - Static config excess_penalty not in static configuration, trying to skip it.
# 2026-06-03 14:16:03.405 | INFO     | encodapy.service.basic_service:start_calibration:716 - No Information about the calibration time in the configuration. Calibration will not be performed.
# ...
