# %% [markdown]
# # Example for FlixOpt Component
# This notebook shows an example how to run a service with two components. You need to read the [readme.md](./readme.md) and add the `.env` file:
#
# ```
# LOG_LEVEL = "DEBUG"
# FILE_PATH_OF_INPUT_FILE = "./inputs_flixopt.csv"
# ```
#
# Specify the desired configuration in the `.env` file:
# ```
# CONFIG_PATH = "./01_config_example.json"
# ```
# or
# ```
# CONFIG_PATH = "./02_config_example.json"
# PATH_OF_STATIC_DATA = "./static_data_flixopt.json"
# ```

# %%
from encodapy.service.service_main import service_main

# %%
await service_main()
# Out:
# 2026-06-03 14:10:06.156 | INFO     | encodapy.service.basic_service:prepare_basic_start:102 - Prepare the basic start of the service
# 2026-06-03 14:10:06.159 | DEBUG    | encodapy.config.models:check_timestep_units:275 - No timerange type is set - using default type 'absolute'
# 2026-06-03 14:10:06.161 | DEBUG    | encodapy.service.communication.file_connection:load_file_params:54 - Load config for File interface
# 2026-06-03 14:10:06.165 | DEBUG    | encodapy.service.basic_service:_load_config:95 - Config succesfully loaded.
# 2026-06-03 14:10:06.168 | DEBUG    | encodapy.components.basic_component:set_component_config_data:208 - Static config excess_penalty not in static configuration, trying to skip it.
# 2026-06-03 14:10:06.178 | INFO     | encodapy.service.basic_service:start_calibration:716 - No Information about the calibration time in the configuration. Calibration will not be performed.
# 2026-06-03 14:10:06.179 | DEBUG    | encodapy.service.basic_service:check_health_status:748 - Start the Health-Check
# 2026-06-03 14:10:06.182 | INFO     | encodapy.service.basic_service:start_service:671 - Start the Service
# 2026-06-03 14:10:06.183 | DEBUG    | encodapy.service.basic_service:start_service:680 - Start the Process
# 2026-06-03 14:10:06.183 | DEBUG    | encodapy.service.communication.file_connection:get_data_from_file:112 - load inputdata from .csv -file
# 2026-06-03 14:10:06.193 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for heat_demand: {'entity': 'flixopt_input_entity', 'attribute': 'heat_demand'}
# 2026-06-03 14:10:06.194 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for electricity_demand: {'entity': 'flixopt_input_entity', 'attribute': 'electricity_demand'}
# 2026-06-03 14:10:06.194 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for electricity_price: {'entity': 'flixopt_input_entity', 'attribute': 'electricity_price'}
# 2026-06-03 14:10:06.195 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for storage_level: {'entity': 'flixopt_input_test', 'attribute': 'storage_level'}
# 2026-06-03 14:10:06.197 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:270 - Processing input heat_demand with value type <class 'dict'>
# 2026-06-03 14:10:06.200 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:270 - Processing input electricity_demand with value type <class 'dict'>
# 2026-06-03 14:10:06.202 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:270 - Processing input electricity_price with value type <class 'dict'>
# 2026-06-03 14:10:06.204 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:270 - Processing input storage_level with value type <class 'dict'>
# 2026-06-03 14:10:06.492 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:_prepare_flixopt_flow_system:335 - Prepared FlowSystem with 3 buses and 1 effects.
# 2026-06-03 14:10:08.171 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 -  Solve problem using Highs solver
# 2026-06-03 14:10:08.172 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 - Solver logs written to `C:\Users\Beyer\AppData\Local\Temp\flixopt_solver_utv9l_sb.log`.
# 2026-06-03 14:10:08.173 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 - Solver options:
#  - mip_rel_gap: 0.01
#  - time_limit: 60
#  - log_to_console: False
# 2026-06-03 14:10:08.600 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 - Writing objective.
# Writing constraints.: 100%|██████████| 87/87 [00:00<00:00, 204.48it/s]
# Writing continuous variables.: 100%|██████████| 66/66 [00:00<00:00, 376.10it/s]
# Writing binary variables.: 100%|██████████| 14/14 [00:00<00:00, 325.67it/s]
# 2026-06-03 14:10:09.270 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 -  Writing time: 0.67s
# 2026-06-03 14:10:09.273 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 - Log file at C:\Users\Beyer\AppData\Local\Temp\flixopt_solver_utv9l_sb.log
# 2026-06-03 14:10:09.406 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 -  Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 914 primals, 1001 duals
# Objective: -3.33e+00
# Solver model: available
# Solver message: Optimal
#
# 2026-06-03 14:10:09.809 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:run_optimization:920 - Optimization completed with a duration for modeling 1.6714546999428421 s and solving 1.6397233000025153 s. The main objective result is -3.3266666666666644.
# 2026-06-03 14:10:09.847 | DEBUG    | encodapy.service.basic_service:send_outputs:505 - Finished sending output data
# 2026-06-03 14:11:06.188 | DEBUG    | encodapy.service.basic_service:start_service:680 - Start the Process
# 2026-06-03 14:11:06.189 | DEBUG    | encodapy.service.communication.file_connection:get_data_from_file:112 - load inputdata from .csv -file
# 2026-06-03 14:11:06.219 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for heat_demand: {'entity': 'flixopt_input_entity', 'attribute': 'heat_demand'}
# 2026-06-03 14:11:06.220 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for electricity_demand: {'entity': 'flixopt_input_entity', 'attribute': 'electricity_demand'}
# 2026-06-03 14:11:06.221 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for electricity_price: {'entity': 'flixopt_input_entity', 'attribute': 'electricity_price'}
# 2026-06-03 14:11:06.222 | DEBUG    | encodapy.components.basic_component:set_input_data:317 - Processing input configuration for storage_level: {'entity': 'flixopt_input_test', 'attribute': 'storage_level'}
# 2026-06-03 14:11:06.223 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:270 - Processing input heat_demand with value type <class 'dict'>
# 2026-06-03 14:11:06.224 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:270 - Processing input electricity_demand with value type <class 'dict'>
# 2026-06-03 14:11:06.226 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:270 - Processing input electricity_price with value type <class 'dict'>
# 2026-06-03 14:11:06.227 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:prepare_input_data:270 - Processing input storage_level with value type <class 'dict'>
# 2026-06-03 14:11:06.231 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:_prepare_flixopt_flow_system:335 - Prepared FlowSystem with 3 buses and 1 effects.
# 2026-06-03 14:11:07.482 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 -  Solve problem using Highs solver
# 2026-06-03 14:11:07.483 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 - Solver logs written to `C:\Users\Beyer\AppData\Local\Temp\flixopt_solver_w_d0gj9j.log`.
# 2026-06-03 14:11:07.484 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 - Solver options:
#  - mip_rel_gap: 0.01
#  - time_limit: 60
#  - log_to_console: False
# 2026-06-03 14:11:07.787 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 - Writing objective.
# Writing constraints.: 100%|██████████| 87/87 [00:00<00:00, 175.15it/s]
# Writing continuous variables.: 100%|██████████| 66/66 [00:00<00:00, 438.21it/s]
# Writing binary variables.: 100%|██████████| 14/14 [00:00<00:00, 462.38it/s]
# 2026-06-03 14:11:08.482 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 -  Writing time: 0.7s
# 2026-06-03 14:11:08.484 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 - Log file at C:\Users\Beyer\AppData\Local\Temp\flixopt_solver_w_d0gj9j.log
# 2026-06-03 14:11:08.642 | INFO     | encodapy.components.flixopt_model_component.flixopt_model_component:emit:45 -  Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 914 primals, 1001 duals
# Objective: -3.33e+00
# Solver model: available
# Solver message: Optimal
#
# 2026-06-03 14:11:08.921 | DEBUG    | encodapy.components.flixopt_model_component.flixopt_model_component:run_optimization:920 - Optimization completed with a duration for modeling 1.2453218000009656 s and solving 1.4410508999135345 s. The main objective result is -3.3266666666666644.
# 2026-06-03 14:11:08.965 | DEBUG    | encodapy.service.basic_service:send_outputs:505 - Finished sending output data
# 2026-06-03 14:11:54.608 | DEBUG    | encodapy.service.basic_service:start_service:707 - Service will be stopped, running cleanup
# 2026-06-03 14:11:54.609 | DEBUG    | encodapy.service.basic_service:cleanup_service:657 - Service stopped, cleanup finished.
# 2026-06-03 14:11:54.609 | INFO     | encodapy.service.service_main:service_main:96 - Service successfully stopped
